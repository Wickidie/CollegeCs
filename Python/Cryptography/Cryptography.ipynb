# %%
# Vinegere  =   Key dilanjut key (ditambah) (key + txt)
# Beuford   =   Key dilanjut key (dikurang) (key - txt)
# Autokey   =   Key dilanjut dengan txt (ditambah) (key + txt)

# txt = MAKANMALAM
# key = FULL

#   Beuford
#   F   U   L   L   F   U   L   L   F   U 
#   5   20  11  11  5   20  11  11  5   20
#   M   A   K   A   N   M   A   L   A   M
#   12  0   10  0   13  12  0   11  0   12
#   -
#   -7  20  1   11  -8  8   11  0   5   8
#   MOD 26
#   19  20  1   11  18  8   11  0   5   8
#   T   U   B   L   S   I   L   A   F   I

#   Permutation of Letters

#   
#   
#   
#   
#   
#  
 
#   Road blablabla
#   k = 3, offset = 2

#   txt = PULANGMALAMKRIPTOGRAFI
#   key = 
P   U   L   A   N   G   M   A   L   A   M   K   R   I   P   T   O   G   R   A   F   I
#   
U   I   R
O   F   M
L   B   S
K   I   T
G   A   I
A   A   P
R   

U   I   R   O   F   M   L
B   S   K   I   T   G   A
I   A   A   P   R   

19
U   I   R   O   F   M   L   B   S   K   I   T   G   A   I   A   A   P   R   

U   I   R   O   F   
M   L   B   S   K   
I   T   G   A   I   
A   A   P   R   

 U   I   R   O   F   
M L B S K I T G A I 
   A   A   P   R
UIROFMLBSKITGAIAAPR

key = MALAM

#   
#   
#   
#   
#   
#   
#   
#   
#   
#   
#   
#   
#   
#   
#   
#
